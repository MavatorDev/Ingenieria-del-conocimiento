# %%
from os import listdir

# %%
listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'clustering.ipynb',
#  'desktop.ini',
#  'energydata.csv',
#  'IntroAnsysInputfiles',
#  'Microsoft Edge.lnk']

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data=pd.read_csv('energydata.csv')
df=pd.DataFrame(data)
#print(df)
#print(df.keys())

# %%
x=df['T_out']
y=df['RH_out']

X=np.array(list(zip(x,y)))
#print(X)

# %%
kmeans=KMeans(n_clusters=3) 
kmeans=kmeans.fit(X)
labels=kmeans.predict(X)
centroids=kmeans.cluster_centers_

# %%
# %matplotlib inline

# %%
idx = np.random.random() * len(X)
idx
# Out:
# 7828.250013840728

# %%
print(centroids)
colores=["b.","y.","r.","c.","m."]
fig = plt.figure()
for i in range(0, 1000):
    #print("Coordenada: ",X[i]," Label: ",labels[i])
    idx = int(np.random.rand() * len(X))
    plt.plot(X[idx][0],X[idx][1], colores[labels[idx]], markersize=10)

plt.scatter(centroids[:,0], centroids[:,1], marker='x', s=250, linewidths=10,zorder=10, color=("red", "blue", "white"))

fig.savefig('grafica2.png')
plt.show()
# Out:
# [[ 8.09755916 74.09679773]
#  [ 5.11500435 91.20327464]
#  [13.64779632 53.15473898]]
